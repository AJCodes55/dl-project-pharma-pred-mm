# %% [markdown]
# ## Phase 7 Full Evaluation (Local Runbook)
#
# Run top-to-bottom:
# 1. Local project setup
# 2. Dependencies (if needed)
# 3. Run full cross-phase evaluation
# 4. Inspect final artifacts

# %%
from pathlib import Path
import os
import sys

PROJECT_DIR = Path.cwd()
if not (PROJECT_DIR / 'phase7_full_evaluation.py').exists():
    PROJECT_DIR = Path('/Users/aj5/Main drive/UT Austin MSIS/Deep Learning/Project ')

os.chdir(PROJECT_DIR)
print('cwd:', os.getcwd())
print('python:', sys.executable)
print('phase7 script exists:', Path('phase7_full_evaluation.py').exists())
# Out:
# cwd: /Users/aj5/Main drive/UT Austin MSIS/Deep Learning/Project
# python: /Users/aj5/Main drive/UT Austin MSIS/Deep Learning/Project /.venv/bin/python
# phase7 script exists: True

# %%
# Dependencies (safe to rerun)
# %pip install -q numpy pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import subprocess
import sys

cmd = [
    sys.executable,
    'phase7_full_evaluation.py',
    '--project-root', str(PROJECT_DIR),
    '--results-root', 'results',
    '--feature-config-path', 'processed/feature_config.json',
    '--fda-events-path', 'All data DL project/fda_event_calendar.csv',
    '--output-dir', 'results/phase7_analysis',
    '--n-bootstrap', '2000',
    '--bootstrap-seed', '42',
    '--case-study-count', '5',
]
print('Running:', ' '.join(cmd))
subprocess.run(cmd, check=True)
# Out:
# Running: /Users/aj5/Main drive/UT Austin MSIS/Deep Learning/Project /.venv/bin/python phase7_full_evaluation.py --project-root /Users/aj5/Main drive/UT Austin MSIS/Deep Learning/Project  --results-root results --feature-config-path processed/feature_config.json --fda-events-path All data DL project/fda_event_calendar.csv --output-dir results/phase7_analysis --n-bootstrap 2000 --bootstrap-seed 42 --case-study-count 5
# Saved Phase 7 artifacts:
#  - /Users/aj5/Main drive/UT Austin MSIS/Deep Learning/Project /results/phase7_analysis/phase7_master_metrics.csv
#  - /Users/aj5/Main drive/UT Austin MSIS/Deep Learning/Project /results/phase7_analysis/phase7_master_equity_curve.csv
#  - /Users/aj5/Main drive/UT Austin MSIS/Deep Learning/Project /results/phase7_analysis/phase7_master_daily_returns.csv
#  - /Users/aj5/Main drive/UT Austin MSIS/Deep Learning/Project /results/phase7_analysis/phase7_bootstrap_sharpe_ci.csv
# ...

# %%
from pathlib import Path
import pandas as pd

base = Path('results/phase7_analysis')
paths = {
    'master_metrics': base / 'phase7_master_metrics.csv',
    'master_equity': base / 'phase7_master_equity_curve.csv',
    'master_daily_returns': base / 'phase7_master_daily_returns.csv',
    'bootstrap_ci': base / 'phase7_bootstrap_sharpe_ci.csv',
    'bootstrap_delta_ci': base / 'phase7_bootstrap_sharpe_delta_ci.csv',
    'interpretability': base / 'phase7_interpretability_summary.csv',
    'case_studies': base / 'phase7_case_studies.csv',
    'summary_md': base / 'phase7_final_summary.md',
}

for name, p in paths.items():
    print(f'{name}:', 'OK' if p.exists() else 'MISSING', '-', p)

if paths['master_metrics'].exists():
    print('\nMaster metrics:')
    display(pd.read_csv(paths['master_metrics']))
if paths['bootstrap_ci'].exists():
    print('\nBootstrap Sharpe CI:')
    display(pd.read_csv(paths['bootstrap_ci']))
if paths['case_studies'].exists():
    print('\nCase studies:')
    display(pd.read_csv(paths['case_studies']).head(20))
# Out:
# master_metrics: OK - results/phase7_analysis/phase7_master_metrics.csv
# master_equity: OK - results/phase7_analysis/phase7_master_equity_curve.csv
# master_daily_returns: OK - results/phase7_analysis/phase7_master_daily_returns.csv
# bootstrap_ci: OK - results/phase7_analysis/phase7_bootstrap_sharpe_ci.csv
# bootstrap_delta_ci: OK - results/phase7_analysis/phase7_bootstrap_sharpe_delta_ci.csv
# interpretability: OK - results/phase7_analysis/phase7_interpretability_summary.csv
# case_studies: OK - results/phase7_analysis/phase7_case_studies.csv
# summary_md: OK - results/phase7_analysis/phase7_final_summary.md
#
# Master metrics:
#                 strategy  cumulative_return_pct  ann_sharpe  ann_sortino  \
# 0         PPO_Phase6_SEC              27.636315    0.768130     1.275613
# 1    PPO_Phase5_BasicFDA              25.431256    0.613396     1.061182
# 2          PPO_PriceOnly              12.106765    0.445379     0.718082
# ...
